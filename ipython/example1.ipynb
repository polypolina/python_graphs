# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.axes as ax

# %%
  datalist = [
      {'date': 1, 'value': 100},
      {'date': 2, 'value': 200},
      {'date': 3, 'value': 300},
      {'date': 3, 'value': 400},
      {'date': 3, 'value': 500},
      {'date': 4, 'value': 600},
      {'date': 5, 'value': 700},
      {'date': 6, 'value': 700},
      {'date': 7, 'value': 700},
      {'date': 7, 'value': 200}
  ]

# %%
df = pd.DataFrame(datalist)
df.head()
# df.tail(6)
# Out:
#    date  value
# 0     1    100
# 1     2    200
# 2     3    300
# 3     3    400
# 4     3    500

# %%
print(df['value'][3])
# Out:
# 400

# %%
df.hist(column = ['date'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023C6C2D50A0>]],
#       dtype=object)

# %%
df.plot()
plt.show()
